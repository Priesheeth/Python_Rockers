# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#ExtraQ 5: Retrieve the rows of data based on descending order of BloodPressureSystolic.
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
dbp = df.sort_values(['BloodPressureSystolic'], ascending=[0])
dbp
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 236      933         884          27  2019-02-14 2019-01-22 19:26:49.163
# 424      314          63           7  2019-04-05 2019-03-24 22:31:26.092
# 251      888         906          24  2019-03-31 2019-03-17 23:21:17.361
# 677      929         880          23  2019-02-10 2019-01-22 13:32:14.549
# 934      482         866          14  2019-05-04 2019-04-13 07:54:49.580
# ..       ...         ...         ...         ...                     ...
# 805      666         818          33  2019-02-09 2019-02-01 02:22:14.761
# 807      555          72          35  2019-04-30 2019-04-02 08:38:32.357
# 808      645          90          37  2019-03-16 2019-02-16 17:45:16.908
# 810      773         858          24  2019-03-12 2019-02-25 02:59:43.233
# 813      895         913          31  2019-04-07 2019-03-23 15:12:55.426
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 236                 12  Telemedicine                  190.0
# 424                 11  Telemedicine                  190.0
# 251                 10           New                  190.0
# 677                  8     Follow Up                  190.0
# 934                  5           New                  190.0
# ..                 ...           ...                    ...
# 805                 10      Physical                    NaN
# 807                  7     Follow Up                    NaN
# 808                  1  Telemedicine                    NaN
# 810                  2     Follow Up                    NaN
# 813                  7           New                    NaN
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 236              143.989174  74.976879   Completed
# 424              121.539859  95.471260   Completed
# 251              137.207999  52.666922   Completed
# 677              144.313400  82.781940   Completed
# 934              124.736359  69.731779    Canceled
# ..                      ...        ...         ...
# 805                     NaN        NaN   Completed
# 807                     NaN        NaN   Completed
# 808                     NaN        NaN   Completed
# 810                     NaN        NaN   Completed
# 813                     NaN        NaN   Completed
#
# [950 rows x 11 columns]

# %%
#ExtraQ 6: Delete the column 'Acuity' using pop function
EDVisit= pd.read_excel("HospitalDatabase .xlsx",sheet_name="EDVisits")
block = pd.DataFrame(EDVisit)
block.pop('Acuity')
print("\nData frame after deleting the column 'Acuity':\n")
block.head()
# Out:
# Data frame after deleting the column 'Acuity':
#    EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0          1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1         12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2         13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3         14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4         15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
#
#   ReasonForVisit EDDisposition
# 0   Stomach Ache      Admitted
# 1       Migraine      Admitted
# 2   Stomach Ache      Admitted
# 3       Migraine      Admitted
# 4     Chest Pain      Admitted

# %%
#ExtraQ 7:Display the data for all 'Black/African-American English Female' patients
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name="Patients")

Patients_df = df[(df.Race == 'Black/African-American') & (df.Gender == 'Female') & (df.Language == 'English')]
Patients_df
# Out:
#      PatientID  FirstName  LastName             DateOfBirth  Gender  \
# 120        121     Granny  Prandoni 1984-12-26 04:09:28.604  Female
# 121        122      Hilll      Nock 1966-03-28 19:01:51.451  Female
# 122        123  Pollyanna    Mochan 1973-05-06 06:39:21.883  Female
# 123        124     Lucila   McGrann 1972-03-06 15:34:40.549  Female
# 124        125        Mia       Inc 1971-03-21 15:38:42.818  Female
# ..         ...        ...       ...                     ...     ...
# 914        915   Jerrilyn     Dyson 1978-01-18 02:41:55.178  Female
# 915        916     Kaylil   Baldack 1966-11-17 14:10:35.224  Female
# 916        917     Velvet  Bushnell 1965-11-13 07:26:58.889  Female
# 917        918       Kiri     Allom 1960-09-05 13:21:10.008  Female
# 918        919   Champlin   Bulford 1979-07-01 16:14:46.649  Female
#
#                        Race Language
# 120  Black/African-American  English
# 121  Black/African-American  English
# 122  Black/African-American  English
# 123  Black/African-American  English
# 124  Black/African-American  English
# ..                      ...      ...
# 914  Black/African-American  English
# 915  Black/African-American  English
# 916  Black/African-American  English
# 917  Black/African-American  English
# 918  Black/African-American  English
#
# [119 rows x 7 columns]

# %%
#ExtraQ 8:Create a boxplot on ExpectedLOS with respect to discharge disposition
dischargesdf=pd.read_excel("HospitalDataBase .xlsx", sheet_name="Discharges")

fig = plt.figure(figsize = (10, 5))
# To create a boxplot
sns.boxplot(x=dischargesdf.DischargeDisposition,y=dischargesdf.ExpectedLOS)
 
plt.show()

# %%
#ExtraQ 9:Retrieve count of patient who are prone to Hypertension crisis (SBP>180 & DBP >120)
df= pd.read_excel("HospitalDatabase .xlsx",sheet_name="AmbulatoryVisits")
Count = print(((df["BloodPressureSystolic"] >= 180) & (df["BloodPressureDiastolic"] >= 120)).sum())
# Out:
# 110

# %%
#ExtraQ 10:Create a bar chart showing Primary Diagnosis with high expected mortality .
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name = "ReAdmissionRegistry")
#To fix the plot size

fig = plt.figure(figsize = (22,12))

#To declare Variable
x = df.PrimaryDiagnosis
y = df.ExpectedMortality

# creat a bar chart
plt.bar(x,y,color='Pink', width=0.5,edgecolor='white')

# To Put label for axis
plt.xlabel("Primary Diagnosis",fontsize=1)
plt.ylabel("ExpectedMortality")
plt.title("Bar chart on Primary Diagnosis vs Expected Mortality", color="black")
# To show chart
plt.show()

# %%
#ExtraQ 11:Create a bar chart showing Service with expected high mortality .
df = pd.read_excel("HospitalDatabase .xlsx",sheet_name = "ReAdmissionRegistry")
#To fix the plot size

fig = plt.figure(figsize = (10, 10))

#To declare Variable
x=df.Service
y=df.ExpectedMortality

# creat a bar chart
plt.bar(x,y,color='lightblue', width=0.7,edgecolor='white')

# To Put label for axis
plt.xlabel("Service")
plt.ylabel("ExpectedMortality")
plt.title("Bar chart on Service vs Expected Mortality", color="black")
# To show chart
plt.show()
